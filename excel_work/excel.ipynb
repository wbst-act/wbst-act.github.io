# %%
import pandas as pd

df=pd.read_excel('2023S2.xlsx', index_col=0)
df.fillna('', inplace=True)
df
# Out:
#                Unnamed: 1           Unnamed: 2   Unnamed: 3 活動組2023年S2例行活動班表  \
# 重要公告
# NaN                    時間                                路線             集合時間
# NaN
# NaN
# NaN
# 序                      4月                   星期
# 43    2023-04-01 00:00:00  2023-04-01 00:00:00
# 44    2023-04-02 00:00:00  2023-04-02 00:00:00          植物園         07:30:00
# 45    2023-04-08 00:00:00  2023-04-08 00:00:00           金山         08:30:00
# 46    2023-04-09 00:00:00  2023-04-09 00:00:00        三芝車新路         07:30:00
# 47    2023-04-15 00:00:00  2023-04-15 00:00:00
# 48    2023-04-16 00:00:00  2023-04-16 00:00:00      觀音山遊客中心         08:30:00
# 49    2023-04-22 00:00:00  2023-04-22 00:00:00        猛禽研究會         08:30:00
# 50    2023-04-23 00:00:00  2023-04-23 00:00:00          挖仔尾         07:30:00
# 51    2023-04-29 00:00:00  2023-04-29 00:00:00
# 52    2023-04-30 00:00:00  2023-04-30 00:00:00         淡江農場         08:00:00
# 白     2023-04-27 00:00:00                   週四          挖仔尾         07:30:00
# 序                      5月                   星期
# 54    2023-05-06 00:00:00  2023-05-06 00:00:00
# 55    2023-05-07 00:00:00  2023-05-07 00:00:00       貴子坑露營區         08:00:00
# 56    2023-05-13 00:00:00  2023-05-13 00:00:00          四崁水         08:15:00
# 57    2023-05-14 00:00:00  2023-05-14 00:00:00          劍南路         07:30:00
# 58    2023-05-20 00:00:00  2023-05-20 00:00:00
# 59    2023-05-21 00:00:00  2023-05-21 00:00:00          內溝里         08:00:00
# 60    2023-05-27 00:00:00  2023-05-27 00:00:00         康誥坑溪         07:30:00
# 61    2023-05-28 00:00:00  2023-05-28 00:00:00          植物園         07:30:00
# 白     2023-05-25 00:00:00                   週四         直潭國小         08:00:00
# 序                      6月                   星期
# 63    2023-06-03 00:00:00  2023-06-03 00:00:00
# 64    2023-06-04 00:00:00  2023-06-04 00:00:00       二叭子植物園         07:00:00
# 65    2023-06-10 00:00:00  2023-06-10 00:00:00  樹梅坑溪(原楓丹白露)         07:30:00
# 66    2023-06-11 00:00:00  2023-06-11 00:00:00         直潭國小         08:00:00
# 67    2023-06-17 00:00:00  2023-06-17 00:00:00
# 68    2023-06-18 00:00:00  2023-06-18 00:00:00         南港公園         07:30:00
# 69    2023-06-24 00:00:00  2023-06-24 00:00:00         青年公園         08:00:00
# 70    2023-06-25 00:00:00  2023-06-25 00:00:00       大安森林公園         07:30:00
# 白     2023-06-29 00:00:00                   週四          植物園         07:30:00
#
#      Unnamed: 5 Unnamed: 6                                         Unnamed: 7  \
# 重要公告
# NaN        紀錄鳥種       民眾人數                                               集合地點
# NaN
# NaN
# NaN
# 序
# 43
# 44                                                                捷運小南門站(出口3)
# 45                                                         金山青年活動中心(國光客運1815)
# 46                                                                 捷運淡水站(出口1)
# 47
# 48                                                           觀音山遊客中心站(公車 橘20)
# 49                                                    文化大學站(公車260/111/紅5/小15)
# 50                                                                 捷運關渡站(出口1)
# 51
# 52                                                                輕軌淡江大學站(出口)
# 白                                                                  捷運關渡站(出口1)
# 序
# 54
# 55                          貴子坑水土保持園區公車站 (公車218/226/223/216/620 貴子坑水土保持園區公車站)
# 56                                         台電訓練所門口(公車849台電訓練所站/新巴士龜山線龜山活動中心站)
# 57                                                                捷運劍南路站(出口1)
# 58
# 59                               內溝敦厚宮(公車281/287(內湖幹線)/287區/小1/小1區 南寮(忠三街口)站)
# 60                                                              捷運南港展覽館站(出口6)
# 61                                                                捷運小南門站(出口3)
# 白                                                        新烏路長興宮(公車849/綠3小粗坑站)
# 序
# 63
# 64                                                                  捷運新店站(出口)
# 65                                                                 捷運竹圍站(出口1)
# 66                                                       新烏路長興宮(公車849/綠3小粗坑站)
# 67
# 68                                                                 捷運昆陽站(出口4)
# 69                                                                    青年公園2號門
# 70                                                             捷運大安森林公園站(出口2)
# 白                                                                 捷運小南門站(出口3)
#
#      Unnamed: 8 Unnamed: 9 Unnamed: 10  ...       Unnamed: 16 Unnamed: 17  \
# 重要公告                                    ...
# NaN          公里        鳥種數        解說人員  ...               華江橋
# NaN                                     ...
# NaN                                主領隊  ...  上午\n 08:30-11:30
# NaN                                     ...
# 序                                       ...
# 43                                      ...
# 44          2km         45         詹駿鴻  ...               鍾文傑         黃斐嬋
# 45          6km         50         溫小慧  ...
# 46          4km         40         周暉堡  ...               賴建華         何建遙
# 47                                      ...
# 48          1km         20              ...               黃如秀         崔懷空
# 49          2km         20         許勝杰  ...
# 50          2km         50         劉耀文  ...               劉金和         鄒文惠
# 51                                      ...
# 52          4km         40         李昭賢  ...               鄒文惠         蘇昭如
# 白           2km         50         林瑞如  ...
# 序                                       ...
# 54                                      ...
# 55          4km         30         李天助  ...
# 56          5km         40         崔懷空  ...
# 57          2km         25         林廖檥  ...
# 58                                      ...
# 59          5km         40         李政洋  ...
# 60          4km         35         沈彩鳳  ...
# 61          2km         45         許棠禎  ...
# 白           6km         40         王曉慧  ...
# 序                                       ...
# 63                                      ...
# 64          4km         35         王曉慧  ...
# 65          5km         40         簡御仁  ...
# 66          6km         40         莊靜宜  ...
# 67                                      ...
# 68          2km         40         蘇平和  ...
# 69          2km         25              ...
# 70          2km         35         李政洋  ...
# 白           2km         45         陳英井  ...
#
#                                             Unnamed: 18 Unnamed: 19  \
# 重要公告  *3月1日至5月底整修\n將改至月池平台及2號賞鳥小屋\n當日可自行選擇於何處       ...
# NaN                                              關渡自然公園
# NaN                                         月池平台/2號賞鳥小屋
# NaN                                     上午\n 9:00-12:00
# NaN
# 序
# 43                                                   許財
# 44                                                  黃如秀         崔懷空
# 45                                                  李明昆         李秀春
# 46                                                              楊啓姚
# 47                                                  鄭農祥         許菀庭
# 48                                                  李明昆         劉華森
# 49                                                  黃斐嬋         王世平
# 50                                                  曾秀梅         鄭安宏
# 51                                                  李明昆         劉麗貞
# 52                                                  梁麗貞         許菀庭
# 白
# 序
# 54                                                  劉后晨         何建遙
# 55                                                  鄭栩伶
# 56                                                  施曉雯         張靜宜
# 57                                                  林明沛         鄭安宏
# 58                                                  李秀春         李昭賢
# 59                                                  黃以忠         杜竟良
# 60                                                  劉麗貞         鄭農祥
# 61                                                   許財         梁麗貞
# 白
# 序
# 63                                                  鍾文傑         張靜宜
# 64                                                  黃家哲         陳鳳珠
# 65                                                  蕭桂珍         邱淑瑜
# 66                                                  鄭安宏         杜竟良
# 67                                                   許財
# 68                                                  吳怡瑩         黃家哲
# 69                                                  伍曼卿         陳瑞芬
# 70                                                  林冠伶         周暉堡
# 白
#
#            Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23       Unnamed: 24  \
# 重要公告
# NaN                                                                   芝 山綠 園
# NaN
# NaN   下午\n 14:00-17:00                                      下午\n 14:00-17:00
# NaN
# 序
# 43                             鄭淑萍
# 44                                                     鄭淑萍               林廖檥
# 45                 李昭賢         曾雲龍
# 46                 史蘭亭         黃有生         江麗華                           簡御仁
# 47                             鄭淑萍
# 48                 史蘭亭         張文綏                                       曾韞琛
# 49                 高儷瑛
# 50                 朱立珮         周成蕙         許棠禎         劉耀文               曾秀梅
# 51                 高儷瑛         曾雲龍
# 52                 黃貞勤         蘇昭如                                       曾韞琛
# 白
# 序
# 54                 黃有生         林再盛
# 55                                                                       陳世耀
# 56                 黃家哲
# 57                                                                       簡御仁
# 58                 高儷瑛
# 59
# 60                 林廖檥         沈彩鳳
# 61                                                                       劉華森
# 白
# 序
# 63                 黃有生         陳鳳珠
# 64                 鄭栩伶         陳鳳珠                                       徐瑞琦
# 65                 蕭桂珍         何建遙
# 66                 石瑞德         石瑞德                                       徐瑞琦
# 67
# 68                                                                       陳湘菱
# 69                 伍曼卿         陳瑞芬
# 70
# 白
#
#       Unnamed: 25
# 重要公告
# NaN
# NaN
# NaN           備註：
# NaN
# 序
# 43          清明節連假
# 44          清明節連假
# 45
# 46
# 47
# 48
# 49    10點至猛禽研究會參訪
# 50        12:27高潮
# 51
# 52
# 白        10:04 低潮
# 序
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# 61
# 白
# 序
# 63
# 64
# 65
# 66
# 67            補班日
# 68
# 69          端午節連假
# 70          端午節連假
# 白
#
# [37 rows x 25 columns]

# %%
data=[]
fieldname =['date','type','name','starttime','endtime','location','distance','birds','p1','p2','p3','p4', 'ebird','cancel','cancel_help']
for i in range (3, df.shape[0]):
    # 例行
    if type(df.iat[i, 0]) != str and not pd.isnull(df.iat[i, 2]) and not pd.isnull(df.iat[i, 7]) and  df.iat[i,7].strip() !='會員大會(不排)':
        print(df.iat[i, 0].weekday(), df.iat[i, 0],  df.iat[i, 2],  df.iat[i, 3],  df.iat[i, 4],df.iat[i, 5], df.iat[i, 7], df.iat[i, 8], df.iat[i, 9], df.iat[i, 10])
        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': df.iat[i, 0].weekday()==3 :'白頭翁' ? '例行',
            'name': df.iat[i, 2].strip(),
            'starttime': df.iat[i, 3].strftime('%H:%M'),
            'endtime': '12:00',
            'location': df.iat[i, 4],
            'distance': df.iat[i, 5],
            'birds': df.iat[i, 6],
            'p1': df.iat[i, 7].strip(),
            'p2': df.iat[i, 8].strip(),
            'p3': df.iat[i, 9].strip(),
            'p4': df.iat[i, 10].strip(),

        })
        

        
print(data)
# Out:
#   Cell In[2], line 9
#     'type': df.iat[i, 0].weekday()==3 :'白頭翁' ? '例行',
#                                       ^
# SyntaxError: invalid syntax

# %%
data=[]
for i in range (3, df.shape[0]):
    # 關渡二樓
    if type(df.iat[i, 0]) != str and not pd.isnull(df.iat[i, 21]):
        print(i, df.iat[i, 0],  df.iat[i, 21],  df.iat[i, 22],  df.iat[i, 23],  df.iat[i, 24])
        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '駐站',
            'name': '關渡自然公園中心二樓',
            'starttime': '09:00',
            'endtime': '12:00',
            'p1': df.iat[i, 21].strip(),
            'p2': df.iat[i, 22].strip(),
        })
        if df.iat[i, 23].strip() != '*會員大會例行暫停1次':
            data.append({
                'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
                'type': '駐站',
                'name': '關渡自然公園中心二樓',
                'starttime': '14:00',
                'endtime': '17:00',
                'p1': df.iat[i, 23].strip(),
                'p2': df.iat[i, 24].strip(),
            })
print(data)
# Out:
# [{'date': '2021/01/02', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '鄭栩伶', 'p2': '伍曼卿'}, {'date': '2021/01/02', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '黃英珍', 'p2': '林再盛'}, {'date': '2021/01/03', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '黃莉鈐', 'p2': '陳忠城'}, {'date': '2021/01/03', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '陳瑞芬', 'p2': '徐瑞琦'}, {'date': '2021/01/09', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '李明昆', 'p2': '劉麗貞'}, {'date': '2021/01/09', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '黃有生', 'p2': '盧春福'}, {'date': '2021/01/10', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '鄭農祥', 'p2': '王新雄'}, {'date': '2021/01/10', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '劉新白', 'p2': '陳正隆'}, {'date': '2021/01/16', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '李秀春', 'p2': '王世平'}, {'date': '2021/01/16', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '江政杰', 'p2': '周憲毅'}, {'date': '2021/01/17', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '許財', 'p2': '鄭安宏'}, {'date': '2021/01/17', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '王曉慧', 'p2': '陳宣宏'}, {'date': '2021/01/23', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '黃以忠', 'p2': '何建遙'}, {'date': '2021/01/23', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '張文綏', 'p2': '葉玲瑤'}, {'date': '2021/01/24', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '崔懷空', 'p2': '黃如秀'}, {'date': '2021/01/24', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '許建忠', 'p2': '高凌宇'}, {'date': '2021/01/30', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '盧瑞雯', 'p2': '李振輝'}, {'date': '2021/01/30', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '杜竟良', 'p2': '劉新白'}, {'date': '2021/01/31', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '梁麗貞', 'p2': '吳怡瑩'}, {'date': '2021/01/31', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '蘇平和', 'p2': '陳英井'}, {'date': '2021/02/06', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '沈彩鳳', 'p2': '林廖檥'}, {'date': '2021/02/06', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '黃有生', 'p2': '陳鳳珠'}, {'date': '2021/02/07', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '蔡淑清', 'p2': '陳鳳珠'}, {'date': '2021/02/07', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '許建忠', 'p2': '陳鳳珠'}, {'date': '2021/02/20', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '邱淑瑜', 'p2': '林詩律'}, {'date': '2021/02/20', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '袁淑玲', 'p2': '周憲毅'}, {'date': '2021/02/21', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '鄭安宏', 'p2': '許財'}, {'date': '2021/02/21', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '李天助', 'p2': '陳英井'}, {'date': '2021/02/27', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '李明昆', 'p2': '劉麗貞'}, {'date': '2021/02/27', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '14:00', 'endtime': '17:00', 'p1': '林詩律', 'p2': '劉麗貞'}, {'date': '2021/02/28', 'type': '駐站', 'name': '關渡自然公園中心二樓', 'starttime': '09:00', 'endtime': '12:00', 'p1': '杜竟良', 'p2': '張靜宜'}, {'date': '2021/02/28', 'type': '駐 ...

# %%
data=[]
for i in range (3, df.shape[0]):
    # 賞鳥趣
    if type(df.iat[i, 0]) != str and not pd.isnull(df.iat[i, 25]):
        print(i, df.iat[i, 0],  df.iat[i, 25],  df.iat[i, 26])
        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '賞鳥趣',
            'name': '關渡自然公園中心',
            'starttime': '14:00',
            'endtime': '17:00',
            'p1': df.iat[i, 25].strip(),
            'p2': df.iat[i, 26].strip(),
        })
print(data)
# Out:
# 5 2020-01-03 00:00:00 許勝杰 李松凌
# 8 2020-01-10 00:00:00 江麗華 鄭淑萍
# 11 2020-01-17 00:00:00 許棠禎 林瑞如
# 14 2020-01-24 00:00:00 黃斐嬋 劉美紅
# 17 2020-01-31 00:00:00 林瑞如 游谷樺
# 22 2020-02-07 00:00:00 林廷奕 許棠禎
# 28 2020-02-21 00:00:00 張美雀 李松凌
# 31 2020-02-28 00:00:00 許勝杰 張素慧
# 36 2020-03-07 00:00:00 黃莉鈐 陳宣宏
# 39 2020-03-14 00:00:00 許棠禎 陳忠城
# 42 2020-03-21 00:00:00 許棠禎 陳宣宏
# 45 2020-03-28 00:00:00 許勝杰 許棠禎
# [{'date': '2021/01/03', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '許勝杰', 'p2': '李松凌'}, {'date': '2021/01/10', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '江麗華', 'p2': '鄭淑萍'}, {'date': '2021/01/17', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '許棠禎', 'p2': '林瑞如'}, {'date': '2021/01/24', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '黃斐嬋', 'p2': '劉美紅'}, {'date': '2021/01/31', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '林瑞如', 'p2': '游谷樺'}, {'date': '2021/02/07', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '林廷奕', 'p2': '許棠禎'}, {'date': '2021/02/21', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '張美雀', 'p2': '李松凌'}, {'date': '2021/02/28', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '許勝杰', 'p2': '張素慧'}, {'date': '2021/03/07', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '黃莉鈐', 'p2': '陳宣宏'}, {'date': '2021/03/14', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '許棠禎', 'p2': '陳忠城'}, {'date': '2021/03/21', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '許棠禎', 'p2': '陳宣宏'}, {'date': '2021/03/28', 'type': '賞鳥趣', 'name': '關渡自然公園中心', 'starttime': '14:00', 'endtime': '15:00', 'p1': '許勝杰', 'p2': '許棠禎'}]

# %%
for i in range (3, df.shape[0]):
    # 芝山
    if type(df.iat[i, 0]) != str and not pd.isnull(df.iat[i, 27]) and type(df.iat[i, 27]) != int :
        print(i, df.iat[i, 0],  df.iat[i, 27] )
        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '駐站',
            'name': '芝山綠園',
            'starttime': '14:00',
            'endtime': '17:00',
            'p1': df.iat[i, 27].strip(),
        })
# Out:
# 5 2020-01-03 00:00:00 郭妙霓
# 8 2020-01-10 00:00:00 徐瑞琦
# 11 2020-01-17 00:00:00 曾韞琛
# 14 2020-01-24 00:00:00 林廖檥
# 17 2020-01-31 00:00:00 曾韞琛
# 22 2020-02-07 00:00:00 陳湘菱
# 28 2020-02-21 00:00:00 曾韞琛
# 31 2020-02-28 00:00:00 曾韞琛
# 36 2020-03-07 00:00:00 溫小慧
# 39 2020-03-14 00:00:00 沈彩鳳
# 42 2020-03-21 00:00:00 林進三
# 45 2020-03-28 00:00:00 陳佑瑄

# %%
for i in range (3, df.shape[0]):
    # 大安森林公園
    if type(df.iat[i, 0]) != str and not pd.isnull(df.iat[i, 13]) and not pd.isnull(df.iat[i, 14]):
        print(i, df.iat[i, 0],  df.iat[i, 13],  df.iat[i, 14],  df.iat[i, 15],  df.iat[i, 16])
        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '駐站',
            'name': '大安森林公園',
            'starttime': '08:30',
            'endtime': '11:30',
            'p1': df.iat[i, 13].strip(),
            'p2': df.iat[i, 14].strip(),
        })

        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '駐站',
            'name': '大安森林公園',
            'starttime': '13:30',
            'endtime': '16:30',
            'p1': df.iat[i, 15].strip(),
            'p2': df.iat[i, 16].strip(),
        })
# Out:
# 5 2020-01-03 00:00:00 伍曼卿 鄭永耀 伍曼卿 黃英珍
# 8 2020-01-10 00:00:00 鄭永耀 高凌宇 林明沛 方銘亮
# 11 2020-01-17 00:00:00 董金葉 陳乃淳 董金葉 陳乃淳
# 14 2020-01-24 00:00:00 張文綏 林冠伶 楊永賢 高儷瑛
# 17 2020-01-31 00:00:00 曾秀梅 曾昱智 崔懷空 黃如秀
# 22 2020-02-07 00:00:00 黃國盛 吳怡瑩 方銘亮 陳宣宏
# 28 2020-02-21 00:00:00 黃淑貞 謝奇男 張國相 謝奇男
# 31 2020-02-28 00:00:00 劉美紅 王蕙郁 楊永賢 鄭永耀
# 36 2020-03-07 00:00:00 張筱蕙 張文綏 施曉雯 陳湘菱
# 39 2020-03-14 00:00:00 陳世耀 梁齡之 張國相 曾昱智
# 42 2020-03-21 00:00:00 董金葉 陳乃淳 董金葉 陳乃淳
# 45 2020-03-28 00:00:00 張舒涵 楊義賢 楊永賢 劉新白

# %%
for i in range (3, df.shape[0]):
    # 華江
    if type(df.iat[i, 0]) != str and not pd.isnull(df.iat[i, 17]):
        print(i, df.iat[i, 0],  df.iat[i, 17],  df.iat[i, 18],  df.iat[i, 19],  df.iat[i, 20])
        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '駐站',
            'name': '華江雁鴨公園',
            'starttime': '08:30',
            'endtime': '11:30',
            'p1': df.iat[i, 17].strip(),
            'p2': df.iat[i, 18].strip(),
        })

        data.append({
            'date': (df.iat[i, 0]+pd.DateOffset(years=1)).strftime('%Y/%m/%d'),
            'type': '駐站',
            'name': '華江雁鴨公園',
            'starttime': '13:30',
            'endtime': '16:30',
            'p1': df.iat[i, 19].strip(),
            'p2': df.iat[i, 20].strip(),
        })
# Out:
# 5 2020-01-03 00:00:00 林廷奕 杜竟良 許長生 曾昱智
# 8 2020-01-10 00:00:00 黃斐嬋 劉金和 陳岳輝 林國隆
# 11 2020-01-17 00:00:00 簡御仁 郭妙霓 黃有利 杜竟良
# 14 2020-01-24 00:00:00 鄒文惠 黃斐嬋 陳岳輝 詹駿鴻
# 17 2020-01-31 00:00:00 張舒涵 蔡月娥 曾秀梅 吳清墩
# 22 2020-02-07 00:00:00 鄒文惠 李昭賢 劉耀文 石瑞德
# 28 2020-02-21 00:00:00 簡御仁 林明沛 何建遙 林國隆
# 31 2020-02-28 00:00:00 黃有利 鄒文惠 鍾文傑 王曉慧
# 36 2020-03-07 00:00:00 謝春桃 鄭栩伶 詹駿鴻 陳岳輝
# 39 2020-03-14 00:00:00 王蕙郁 杜竟良 游谷樺 陳世耀
# 42 2020-03-21 00:00:00 黃如秀 鄒文惠 何建遙 林國隆
# 45 2020-03-28 00:00:00 劉美紅 莊靜宜 陳岳輝 詹駿鴻

# %%
a=df.iat[8,24]
print(a)
print(a.strip())
# Out:
# 陳正隆
#
# 陳正隆

# %%
a=df.iat[5, 3]
a.strftime('%H:%M')
# Out:
# '07:30'

# %%
a=df.iat[4,0]
a.strftime('%Y/%m/%d')
a.weekday()
# Out:
# 5

# %%
import csv
fieldname =['date','type','name','starttime','endtime','location','distance','birds','p1','p2','p3','p4', 'ebird','cancel','cancel_help']
with open('tmp.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=fieldname)
    writer.writeheader()
    writer.writerows(data)

# %%
offset = 2
idx={
  'date': 0,
  'name': 2,
  'start': 3,
  'location': 4+offset,
  'distance': 5+offset,
  'birds': 6+offset,
  'p1': 7+offset,
  'p2': 8+offset,
  'p3': 9+offset,
  'p4': 10+offset,
  'd1': 11+offset,
  'd2': 12+offset,
  'd3': 13+offset,
  'd4': 14+offset,
  'h1': 15+offset,
  'h2': 16+offset,
  'h3': 17+offset,
  'h4': 18+offset,
  'k1': 19+offset,
  'k2': 20+offset,
  'k3': 21+offset,
  'k4': 22+offset,
  's1': 23+offset,
  's2': 24+offset,
  'c1': 25+offset
}

# %%
idx['date']
# Out:
# 0
